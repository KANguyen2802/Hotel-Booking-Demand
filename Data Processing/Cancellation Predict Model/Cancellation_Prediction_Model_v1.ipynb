# %% [markdown]
# # Mô hình dự đoán `is_canceled` — Random Forest
#
# Dự đoán xác suất hủy phòng bằng **Random Forest** (scikit-learn) với 6 biến phân loại:
#
# | Biến | Kiểu | Mã hóa |
# |------|------|--------|
# | `deposit_type` | 3 mức | One-Hot Encoding |
# | `market_segment` | 8 mức | One-Hot Encoding |
# | `country` | 178 mức | One-Hot Encoding (gộp nước hiếm → `infrequent`) |
# | `distribution_channel` | 5 mức | One-Hot Encoding |
# | `customer_type` | 4 mức | One-Hot Encoding |
# | `hotel` | 2 mức | One-Hot Encoding |
#
# **Nguyên tắc chống Data Leakage:**
# 1. Chỉ đọc 6 feature + biến mục tiêu — **không** nạp `reservation_status`, `revenue`, `Occupancy_Rate`, `RevPAR`, ...
# 2. `train_test_split` **trước** mọi bước tiền xử lý.
# 3. `OneHotEncoder` chỉ `fit` trên tập train (qua `Pipeline` + `ColumnTransformer`).
# 4. Gộp category hiếm (chủ yếu `country`) dựa trên tần suất train, không dùng thông tin từ test/validation.

# %%
import os
import re
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    RocCurveDisplay,
    classification_report,
    confusion_matrix,
    roc_auc_score,
)
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

warnings.filterwarnings("ignore", category=FutureWarning)

sns.set_theme(style="whitegrid", palette="Set2")
plt.rcParams["figure.figsize"] = (12, 6)
plt.rcParams["font.size"] = 11

RANDOM_STATE = 42
TEST_SIZE = 0.2
DATA_BASENAME = "hotel_bookings"
VERSION_PATTERN = re.compile(rf"^{DATA_BASENAME}_v(\d+)\.csv$", re.IGNORECASE)

# Các cột leakage — KHÔNG được đưa vào mô hình
LEAKAGE_COLUMNS = {
    "reservation_status",       # gần như nhãn của hủy (Canceled = 100%)
    "reservation_status_date",    # ngày ghi nhận trạng thái — sau khi hủy
    "revenue",                    # = adr × total_nights × (1 - is_canceled)
    "Occupancy_Rate",
    "RevPAR",
}

FEATURE_COLUMNS = [
    "deposit_type",
    "market_segment",
    "country",
    "distribution_channel",
    "customer_type",
    "hotel",
]
TARGET_COLUMN = "is_canceled"


def _data_search_roots() -> list[Path]:
    notebook_dir = Path(os.environ.get("VSCODE_NOTEBOOK_DIR", Path.cwd()))
    search_roots = [
        notebook_dir / "data",
        notebook_dir,
        notebook_dir.parent / "data",
        notebook_dir.parent,
        notebook_dir.parent.parent,
        Path.cwd() / "data",
        Path.cwd(),
    ]
    path = Path.cwd()
    for _ in range(6):
        search_roots.extend([path / "data", path])
        path = path.parent

    seen, roots = set(), []
    for root in search_roots:
        try:
            root = root.resolve()
        except OSError:
            continue
        if root not in seen:
            seen.add(root)
            roots.append(root)
    return roots


def find_latest_versioned_data_file() -> Path:
    candidates: list[tuple[int, Path]] = []
    for root in _data_search_roots():
        if not root.is_dir():
            continue
        for file_path in root.glob(f"{DATA_BASENAME}_v*.csv"):
            if "test" in file_path.name.lower():
                continue
            match = VERSION_PATTERN.match(file_path.name)
            if match:
                candidates.append((int(match.group(1)), file_path.resolve()))

    if not candidates:
        raise FileNotFoundError(f"Không tìm thấy file '{DATA_BASENAME}_v*.csv'")

    latest_version, latest_path = max(candidates, key=lambda item: item[0])
    print(f"Chọn file v{latest_version} mới nhất: {latest_path.name}")
    return latest_path


csv_path = find_latest_versioned_data_file()
print(f"Đang đọc: {csv_path}")

# Chỉ đọc feature + target — tránh nạp nhầm cột leakage
df = pd.read_csv(
    csv_path,
    usecols=FEATURE_COLUMNS + [TARGET_COLUMN],
)

print(f"Số booking: {len(df):,}")
print(f"Tỷ lệ hủy: {df[TARGET_COLUMN].mean() * 100:.2f}%")
print(f"\nCột leakage đã loại: {sorted(LEAKAGE_COLUMNS)}")
df.head()
# Out:
# Chọn file v5 mới nhất: hotel_bookings_v5.csv
# Đang đọc: C:\Users\ADMIN\OneDrive\Tài liệu\oneDrive\Desktop\DA\Project\Hotel Booking Demand\Python\data\hotel_bookings_v5.csv
# Số booking: 82,811
# Tỷ lệ hủy: 28.12%
#
# Cột leakage đã loại: ['Occupancy_Rate', 'RevPAR', 'reservation_status', 'reservation_status_date', 'revenue']
#           hotel  is_canceled country market_segment distribution_channel  \
# 0  Resort Hotel            0     PRT         Direct               Direct
# 1  Resort Hotel            0     PRT         Direct               Direct
# 2  Resort Hotel            0     GBR         Direct               Direct
# 3  Resort Hotel            0     GBR      Corporate            Corporate
# 4  Resort Hotel            0     GBR      Online TA                TA/TO
#
#   deposit_type customer_type
# 0   No Deposit     Transient
# 1   No Deposit     Transient
# 2   No Deposit     Transient
# 3   No Deposit     Transient
# 4   No Deposit     Transient

# %% [markdown]
# ## 1. Kiểm tra dữ liệu & chuẩn bị feature

# %%
# Kiểm tra missing và phân bố biến phân loại
print("=== Missing values ===")
print(df[FEATURE_COLUMNS + [TARGET_COLUMN]].isna().sum())

for col in FEATURE_COLUMNS:
    print(f"\n=== {col} ===")
    if col == "country":
        print(df[col].value_counts().head(10))
        print(f"Số quốc gia duy nhất: {df[col].nunique()}")
        print(f"Quốc gia có < 5 booking: {(df[col].value_counts() < 5).sum()}")
    else:
        print(df[col].value_counts())

# Xử lý missing (nếu có) — gán Unknown trước khi split
model_df = df[FEATURE_COLUMNS + [TARGET_COLUMN]].copy()
model_df["country"] = model_df["country"].fillna("Unknown").astype(str)
for col in FEATURE_COLUMNS:
    if col != "country":
        model_df[col] = model_df[col].astype(str)

X = model_df[FEATURE_COLUMNS]
y = model_df[TARGET_COLUMN].astype(int)

print(f"\nKích thước X: {X.shape}")
print(f"Phân bố y: {y.value_counts().to_dict()}")
# Out:
# === Missing values ===
# deposit_type            0
# market_segment          0
# country                 0
# distribution_channel    0
# customer_type           0
# hotel                   0
# is_canceled             0
# dtype: int64
#
# === deposit_type ===
# deposit_type
# No Deposit    81767
# Non Refund      963
# Refundable       81
# Name: count, dtype: int64
#
# === market_segment ===
# market_segment
# Online TA        50391
# Offline TA/TO    12860
# Direct           11351
# Groups            3690
# Corporate         3678
# Complementary      619
# Aviation           220
# Undefined            2
# Name: count, dtype: int64
#
# === country ===
# country
# PRT    25299
# GBR     9921
# FRA     8464
# ESP     6973
# DEU     5109
# ITA     2900
# IRL     2893
# BEL     2022
# BRA     1936
# NLD     1864
# Name: count, dtype: int64
# Số quốc gia duy nhất: 178
# Quốc gia có < 5 booking: 65
#
# === distribution_channel ===
# distribution_channel
# TA/TO        65956
# Direct       12291
# Corporate     4387
# GDS            172
# Undefined        5
# Name: count, dtype: int64
#
# === customer_type ===
# customer_type
# Transient          69939
# Transient-Party     9294
# Contract            3068
# Group                510
# Name: count, dtype: int64
#
# === hotel ===
# hotel
# City Hotel      50686
# Resort Hotel    32125
# Name: count, dtype: int64
#
# Kích thước X: (82811, 6)
# Phân bố y: {0: 59527, 1: 23284}

# %% [markdown]
# ## 2. Train / Test split (trước khi mã hóa)
#
# Tách dữ liệu **trước** mọi bước fit encoder để tránh leakage từ tập test vào quá trình học category.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
    stratify=y,
)

print(f"Train: {len(X_train):,} | Test: {len(X_test):,}")
print(f"Tỷ lệ hủy train: {y_train.mean() * 100:.2f}%")
print(f"Tỷ lệ hủy test:  {y_test.mean() * 100:.2f}%")
# Out:
# Train: 66,248 | Test: 16,563
# Tỷ lệ hủy train: 28.12%
# Tỷ lệ hủy test:  28.12%

# %% [markdown]
# ## 3. Pipeline: One-Hot Encoding → Random Forest
#
# - **OneHotEncoder**: chuyển biến phân loại thành cột nhị phân 0/1.
# - `min_frequency=5`: gộp category hiếm (chủ yếu `country`, `distribution_channel`) thành nhóm `infrequent` — chỉ học từ train.
# - `handle_unknown="infrequent_if_exist"`: category mới ở test không gây lỗi.

# %%
categorical_encoder = OneHotEncoder(
    handle_unknown="infrequent_if_exist",
    min_frequency=5,
    sparse_output=False,
)

preprocessor = ColumnTransformer(
    transformers=[
        ("cat", categorical_encoder, FEATURE_COLUMNS),
    ],
    remainder="drop",
)

rf_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "classifier",
            RandomForestClassifier(
                n_estimators=300,
                max_depth=12,
                min_samples_leaf=20,
                class_weight="balanced",
                random_state=RANDOM_STATE,
                n_jobs=-1,
            ),
        ),
    ]
)

rf_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='infrequent_if_exist',
#                                                                 min_frequency=5,
#                                                                 sparse_output=False),
#                                                   ['deposit_type',
#                                                    'market_segment', 'country',
#                                                    'distribution_channel',
#                                                    'customer_type',
#                                                    'hotel'])])),
#                 ('classifier',
#                  RandomForestClassifier(class_weight='balanced', max_depth=12,
#                                         min_samples_leaf=20, n_estimators=300,
#                                         n_jobs=-1, random_state=42))])

# %% [markdown]
# ## 4. Huấn luyện & đánh giá

# %%
rf_pipeline.fit(X_train, y_train)

y_pred = rf_pipeline.predict(X_test)
y_proba = rf_pipeline.predict_proba(X_test)[:, 1]

print("=== Classification Report (Test) ===")
print(classification_report(y_test, y_pred, target_names=["Không hủy", "Hủy"]))

roc_auc = roc_auc_score(y_test, y_proba)
print(f"ROC-AUC (test): {roc_auc:.4f}")

# Cross-validation trên train (5-fold) — encoder fit trong từng fold
cv_scores = cross_val_score(
    rf_pipeline,
    X_train,
    y_train,
    cv=5,
    scoring="roc_auc",
    n_jobs=-1,
)
print(f"\nCV ROC-AUC (5-fold, train only): {cv_scores.mean():.4f} ± {cv_scores.std():.4f}")
# Out:
# === Classification Report (Test) ===
#               precision    recall  f1-score   support
#
#    Không hủy       0.89      0.49      0.63     11906
#          Hủy       0.39      0.85      0.54      4657
#
#     accuracy                           0.59     16563
#    macro avg       0.64      0.67      0.59     16563
# weighted avg       0.75      0.59      0.61     16563
#
# ROC-AUC (test): 0.7339
#
# CV ROC-AUC (5-fold, train only): 0.7331 ± 0.0047

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred,
    display_labels=["Không hủy", "Hủy"],
    cmap="Blues",
    ax=axes[0],
    colorbar=False,
)
axes[0].set_title("Confusion Matrix (Test)")

RocCurveDisplay.from_predictions(y_test, y_proba, ax=axes[1])
axes[1].set_title(f"ROC Curve — AUC = {roc_auc:.3f}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Phân phối xác suất dự đoán (Prediction Probability Distribution)
#
# So sánh phân phối `P(hủy)` giữa booking **thực sự không hủy** và **thực sự hủy** trên tập test. Mô hình tốt sẽ tách hai nhóm rõ ràng quanh ngưỡng 0,5.
#
# **Quy ước màu:** teal = Không hủy · orange = Hủy

# %%
proba_df = pd.DataFrame(
    {
        "probability": y_proba,
        "actual": np.where(y_test == 1, "Hủy", "Không hủy"),
    }
)

# Đảo màu Set2: teal = Không hủy, orange = Hủy (mặc định seaborn gán ngược lại)
LABEL_ORDER = ["Không hủy", "Hủy"]
LABEL_PALETTE = {"Không hủy": "#66c2a5", "Hủy": "#fc8d62"}

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histogram + KDE chồng lên nhau
sns.histplot(
    data=proba_df,
    x="probability",
    hue="actual",
    hue_order=LABEL_ORDER,
    palette=LABEL_PALETTE,
    bins=30,
    kde=True,
    stat="density",
    common_norm=False,
    alpha=0.45,
    ax=axes[0],
)
axes[0].axvline(0.5, color="black", linestyle="--", linewidth=1.2, label="Ngưỡng 0,5")
axes[0].set_xlabel("Xác suất dự đoán P(hủy)")
axes[0].set_ylabel("Mật độ")
axes[0].set_title("Histogram + KDE — Phân phối xác suất dự đoán")
axes[0].set_xlim(0, 1)
axes[0].legend(title="Thực tế")

# KDE thuần — dễ nhìn sự tách lớp
sns.kdeplot(
    data=proba_df,
    x="probability",
    hue="actual",
    hue_order=LABEL_ORDER,
    palette=LABEL_PALETTE,
    fill=True,
    common_norm=False,
    alpha=0.35,
    linewidth=2,
    ax=axes[1],
)
axes[1].axvline(0.5, color="black", linestyle="--", linewidth=1.2, label="Ngưỡng 0,5")
axes[1].set_xlabel("Xác suất dự đoán P(hủy)")
axes[1].set_ylabel("Mật độ")
axes[1].set_title("KDE — Phân phối xác suất dự đoán")
axes[1].set_xlim(0, 1)
axes[1].legend(title="Thực tế")

plt.tight_layout()
plt.show()

# Thống kê tóm tắt
summary = (
    proba_df.groupby("actual", observed=True)["probability"]
    .agg(["count", "mean", "median", "std"])
    .rename(columns={"count": "n"})
    .reindex(LABEL_ORDER)
)
print("=== Thống kê P(hủy) theo nhãn thực tế (test) ===")
display(summary.round(4))
# Out:
# === Thống kê P(hủy) theo nhãn thực tế (test) ===
#                n    mean  median     std
# actual
# Không hủy  11906  0.4275  0.5029  0.1706
# Hủy         4657  0.5691  0.5868  0.1126

# %% [markdown]
# ## 6. Feature Importance
#
# Sau One-Hot Encoding, mỗi category trở thành một cột số 0/1. Biểu đồ dưới hiển thị top 20 cột quan trọng nhất.

# %%
encoder = rf_pipeline.named_steps["preprocessor"].named_transformers_["cat"]
feature_names = encoder.get_feature_names_out(FEATURE_COLUMNS)
importances = rf_pipeline.named_steps["classifier"].feature_importances_

importance_df = (
    pd.DataFrame({"feature": feature_names, "importance": importances})
    .sort_values("importance", ascending=False)
    .reset_index(drop=True)
)

print(f"Số cột sau One-Hot Encoding: {len(feature_names)}")
print("\nTop 20 feature quan trọng nhất:")
display(importance_df.head(20))

top_n = 20
plot_df = importance_df.head(top_n).iloc[::-1]

fig, ax = plt.subplots(figsize=(10, 8))
ax.barh(plot_df["feature"], plot_df["importance"], color="steelblue")
ax.set_xlabel("Feature Importance (Gini)")
ax.set_title(f"Random Forest — Top {top_n} Feature Importance")
plt.tight_layout()
plt.show()

# Tổng hợp importance theo biến gốc
importance_df["source"] = importance_df["feature"].str.split("_", n=1).str[0]
grouped = (
    importance_df.groupby("source", as_index=False)["importance"]
    .sum()
    .sort_values("importance", ascending=False)
)
print("\nTổng importance theo biến gốc:")
display(grouped)
# Out:
# Số cột sau One-Hot Encoding: 129
#
# Top 20 feature quan trọng nhất:
#                            feature  importance
# 0         market_segment_Online TA    0.183991
# 1                      country_PRT    0.150716
# 2     market_segment_Offline TA/TO    0.102480
# 3       distribution_channel_TA/TO    0.072389
# 4          customer_type_Transient    0.067035
# 5          deposit_type_Non Refund    0.051757
# 6    customer_type_Transient-Party    0.048201
# 7          deposit_type_No Deposit    0.046631
# 8      distribution_channel_Direct    0.043022
# 9            market_segment_Direct    0.037402
# 10                     country_GBR    0.025054
# 11                     country_FRA    0.019951
# 12  distribution_channel_Corporate    0.015506
# 13        market_segment_Corporate    0.015054
# 14              hotel_Resort Hotel    0.013851
# 15          customer_type_Contract    0.013703
# 16           market_segment_Groups    0.013214
# 17                hotel_City Hotel    0.013046
# 18                     country_DEU    0.011698
# 19                     country_ESP    0.006783
# Tổng importance theo biến gốc:
#          source  importance
# 5        market    0.354003
# 0       country    0.257502
# 1      customer    0.131822
# 3  distribution    0.131157
# 2       deposit    0.098620
# 4         hotel    0.026897

# %% [markdown]
# ## 7. Tóm tắt
#
# | Bước | Cách xử lý |
# |------|------------|
# | Loại leakage | Không đọc `reservation_status`, `revenue`, `Occupancy_Rate`, `RevPAR`, ... |
# | Mã hóa số | `OneHotEncoder` → cột nhị phân 0/1 |
# | Chống leakage encoding | `train_test_split` trước, `Pipeline` fit chỉ trên train |
# | Category hiếm | `min_frequency=5` gộp thành `infrequent` (học từ train) |
# | Mô hình | `RandomForestClassifier` (300 cây, `class_weight='balanced'`) |
# | Feature | `deposit_type`, `market_segment`, `country`, `distribution_channel`, `customer_type`, `hotel` |
# | Trực quan hóa | Confusion matrix, ROC, phân phối P(hủy) (histogram + KDE) |
#
# **Lưu ý:** Có thể bổ sung biến số như `lead_time` để cải thiện AUC thêm nữa.
